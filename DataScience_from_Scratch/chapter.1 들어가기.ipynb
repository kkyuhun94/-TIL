# %% [markdown]
# ## 학습정리
# ### 1장. 들어가기
# #### 1.1 데이터 시대의 도래
#    * 방대한 데이터 속에서 아무도 생각해 내지 못했던 수많은 질문에 관한 답이 숨어있다.
#
# #### 1.2 데이터 과학이란?
#    * 데이터 과학 : 지저분한 데이터에서 통찰(insight), 즉 유용한 규칙을 발견
#        * 사례 1. 데이팅 서비스 : 가장 잘 맞는 짝을 찾아줌
#        * 사례 2. 페이스북 : 사용자의 친구들을 연결, 고향,위치 정보를 이용해 이주 패턴등을 찾아줌
#        * 사례 3. Target : 온라인과 오프라인 구매내역 데이터로 예측, 임신을 추정하고 아기용품 광고
#        * 사례 4. 오바마,트럼프 대선 캠프 : 최적의 선거 모금 프로그램, 참여율이 높은 지역, 캠페인의 반응 분석
#        * 그외 : 정부를 더 효율적으로 운영, 공중보건 개선, 사용자의 광고클릭 수를 늘리는 방법 등 다양하게 사용
#
# #### 1.3 동기부여를 위한 상상 : '데이텀 주식회사'의 데이터 과학자가 된다면
#    - 1.3.1 핵심인물 찾기 : 딕셔너리를 통한 데이터 탐색, 네트워크 분석
#    - 1.3.2 데이터 과학자 추천하기 : 추천 시스템
#    - 1.3.3 연봉과 경력 : 데이터 시각화, 단순 회귀 분석
#    - 1.3.4 유료 계정 : 유료 계정 사용 여부를 예측 : 로지스틱 회귀 분석
#    - 1.3.5 관심 주제 : 주제를 뽑는 법 : 자연어 처리
#    - 1.3.6 시작해 보자
